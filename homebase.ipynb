# %%
from apps.generic.services import send_indexer_alert

# %%
send_indexer_alert(msg="into the thread we go")
# Out:
# Successfully sent Discord message to channel 1416003870383145083.
# {'data': 'Status code 200'}
